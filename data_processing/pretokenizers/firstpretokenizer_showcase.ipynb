# %%
import ast
import sys
from pathlib import Path

root = Path().resolve().parent.parent
sys.path.insert(0, str(root))

from pretokenizers.firstpretokenizer import FirstPretokenizer

# %% [markdown]
# ## Pretokenization

# %%
pretokenizer = FirstPretokenizer(_use_dedent=False, _use_semantics=True)
examples = open(f"{root}/utils/code_examples", "r").read().split("\n\n\n\n")

# %%
for example in examples:
    parsed = pretokenizer.pretokenize(ast.parse(example))
    print(f"example:\n{example}\n\nparsed:\n{parsed}\n\n")
# Out:
# example:
# 123
#
# parsed:
# [SEMANTIC_START]123[SEMANTIC_END]
#
#
# example:
# f"sin({a}) is {sin(a):.3}"
#
# parsed:
# [F][QUOT_2][SEMANTIC_START]sin([SEMANTIC_END][DELIMIT_3_L][SEMANTIC_START]a[SEMANTIC_END][DELIMIT_3_R][SEMANTIC_START]) is [SEMANTIC_END][DELIMIT_3_L][SEMANTIC_START]sin[SEMANTIC_END][DELIMIT_1_L][SEMANTIC_START]a[SEMANTIC_END][DELIMIT_1_R][DELIMIT_3_R][QUOT_2]
#
#
# example:
# [1, 2, 3]
#
# parsed:
# [DELIMIT_2_L][SEMANTIC_START]1[SEMANTIC_END][COMMA][SEMANTIC_START]2[SEMANTIC_END][COMMA][SEMANTIC_START]3[SEMANTIC_END][DELIMIT_2_R]
#
#
# example:
# (1, 2, 3)
#
# parsed:
# [TUPLE_L][SEMANTIC_START]1[SEMANTIC_END][COMMA][SEMANTIC_START]2[SEMANTIC_END][COMMA][SEMANTIC_START]3[SEMANTIC_END][TUPLE_R]
#
#
# example:
# {1, 2, 3}
#
# parsed:
# [DELIMIT_3_L][SEMANTIC_START]1[SEMANTIC_END][COMMA][SEMANTIC_START]2[SEMANTIC_END][COMMA][SEMANTIC_START]3[SEMANTIC_END][DELIMIT_3_R]
#
#
# example:
# {"a":1, **d}
#
# parsed:
# [DELIMIT_3_L][QUOT_1][SEMANTIC_START]a[SEMANTIC_END][QUOT_1][DICT_COLON][SEMANTIC_START]1[SEMANTIC_END][COMMA][UNPACK][SEMANTIC_START]d[SEMANTIC_END][DELIMIT_3_R]
#
#
# example:
# a
#
# parsed:
# [SEMANTIC_START]a[SEMANTIC_END]
#
#
# example:
# a = 1
#
# parsed:
# [SEMANTIC_START]a[SEMANTIC_END][ASSIGN][SEMANTIC_START]1[SEMANTIC_END]
#
#
# example:
# del a
#
# parsed:
# [DEL][SEMANTIC_START]a[SEMANTIC_END]
#
#
# example:
# a, *b = it
#
# parsed:
# [SEMANTIC_START]a[SEMANTIC_END][COMMA][REFERENCE][SEMANTIC_START]b[SEMANTIC_END][ASSIGN][SEMANTIC_START]it[SEMANTIC_END]
#
#
# example:
# -a
#
# parsed:
# [USUB][SEMANTIC_START]a[SEMANTIC_END]
#
#
# example:
# not x
#
# parsed:
# [NOT][SEMANTIC_START]x[SEMANTIC_END]
#
#
# example:
# x + y
#
# parsed:
# [SEMANTIC_START]x[SEMANTIC_END][ADD][SEMANTIC_START]y[SEMANTIC_END]
#
#
# example:
# x or y
#
# parsed:
# [SEMANTIC_START]x[SEMANTIC_END][OR][SEMANTIC_START]y[SEMANTIC_END]
#
#
# example:
# 1 <= a < 10
#
# parsed:
# [SEMANTIC_START]1[SEMANTIC_END][LT_E][SEMANTIC_START]a[SEMANTIC_END][LT][SEMANTIC_START]10[SEMANTIC_END]
#
#
# example:
# func(a, b=c, *d, **e)
#
# parsed:
# [SEMANTIC_START]func[SEMANTIC_END][DELIMIT_1_L][SEMANTIC_START]a[SEMANTIC_END][COMMA][REFERENCE][SEMANTIC_START]d[SEMANTIC_END][COMMA][SEMANTIC_START]b[SEMANTIC_END][ASSIGN][SEMANTIC_START]c[SEMANTIC_END][COMMA][KWARGS][SEMANTIC_START]e[SEMANTIC_END][DELIMIT_1_R]
#
#
# example:
# a if b else c
#
# parsed:
# [SEMANTIC_START]a[SEMANTIC_END][IF_COMP][SEMANTIC_START]b[SEMANTIC_END][ELSE_COMP][SEMANTIC_START]c[SEMANTIC_END]
#
#
# example:
# snake.colour
#
# parsed:
# [SEMANTIC_START]snake[SEMANTIC_END][DOT]colour
#
#
# example:
# (x := 4)
#
# parsed:
# [DELIMIT_1_L][SEMANTIC_START]x[SEMANTIC_END][NAMED_EXPR][SEMANTIC_START]4[SEMANTIC_END][DELIMIT_1_R]
#
#
# example:
# l[1:2, 3]
#
# parsed:
# [SEMANTIC_START]l[SEMANTIC_END][DELIMIT_2_L][SEMANTIC_START]1[SEMANTIC_END][SLICE][SEMANTIC_START]2[SEMANTIC_END][COMMA][SEMANTIC_START]3[SEMANTIC_END][DELIMIT_2_R]
#
#
# example:
# l[1:2]
#
# parsed:
# [SEMANTIC_START]l[SEMANTIC_END][DELIMIT_2_L][SEMANTIC_START]1[SEMANTIC_END][SLICE][SEMANTIC_START]2[SEMANTIC_END][DELIMIT_2_R]
#
#
# example:
# [x for x in numbers]
#
# parsed:
# [DELIMIT_2_L][SEMANTIC_START]x[SEMANTIC_END][FOR_COMP][SEMANTIC_START]x[SEMANTIC_END][IN_COMP][SEMANTIC_START]numbers[SEMANTIC_END][DELIMIT_2_R]
#
#
# example:
# {x: x**2 for x in numbers}
#
# parsed:
# [DELIMIT_3_L][SEMANTIC_START]x[SEMANTIC_END][DICT_COLON][SEMANTIC_START]x[SEMANTIC_END][POW][SEMANTIC_START]2[SEMANTIC_END][FOR_COMP][SEMANTIC_START]x[SEMANTIC_END][IN_COMP][SEMANTIC_START]numbers[SEMANTIC_END][DELIMIT_3_R]
#
#
# example:
# {x for x in numbers}
#
# parsed:
# [DELIMIT_3_L][SEMANTIC_START]x[SEMANTIC_END][FOR_COMP][SEMANTIC_START]x[SEMANTIC_END][IN_COMP][SEMANTIC_START]numbers[SEMANTIC_END][DELIMIT_3_R]
#
#
# example:
# [ord(c) for line in file for c in line]
#
# parsed:
# [DELIMIT_2_L][SEMANTIC_START]ord[SEMANTIC_END][DELIMIT_1_L][SEMANTIC_START]c[SEMANTIC_END][DELIMIT_1_R][FOR_COMP][SEMANTIC_START]line[SEMANTIC_END][IN_COMP][SEMANTIC_START]file[SEMANTIC_END][FOR_COMP][SEMANTIC_START]c[SEMANTIC_END][IN_COMP][SEMANTIC_START]line[SEMANTIC_END][DELIMIT_2_R]
#
#
# example:
# (n**2 for n in it if n>5 if n<10)
#
# parsed:
# [DELIMIT_1_L][SEMANTIC_START]n[SEMANTIC_END][POW][SEMANTIC_START]2[SEMANTIC_END][FOR_COMP][SEMANTIC_START]n[SEMANTIC_END][IN_COMP][SEMANTIC_START]it[SEMANTIC_END][IF_COMP][SEMANTIC_START]n[SEMANTIC_END][GT][SEMANTIC_START]5[SEMANTIC_END][IF_COMP][SEMANTIC_START]n[SEMANTIC_END][LT][SEMANTIC_START]10[SEMANTIC_END][DELIMIT_1_R]
#
#
# example:
# [i async for i in soc]
#
# parsed:
# [DELIMIT_2_L][SEMANTIC_START]i[SEMANTIC_END][ASYNC_FOR_COMP][SEMANTIC_START]i[SEMANTIC_END][IN_COMP][SEMANTIC_START]soc[SEMANTIC_END][DELIMIT_2_R]
#
#
# example:
# a = b = 1
#
# parsed:
# [SEMANTIC_START]a[SEMANTIC_END][ASSIGN][SEMANTIC_START]b[SEMANTIC_END][ASSIGN][SEMANTIC_START]1[SEMANTIC_END]
#
#
# example:
# a,b = c
#
# parsed:
# [SEMANTIC_START]a[SEMANTIC_END][COMMA][SEMANTIC_START]b[SEMANTIC_END][ASSIGN][SEMANTIC_START]c[SEMANTIC_END]
#
#
# example:
# x += 2
#
# parsed:
# [SEMANTIC_START]x[SEMANTIC_END][ADD_ASSIGN][SEMANTIC_START]2[SEMANTIC_END]
#
#
# example:
# raise x from y
#
# parsed:
# [RAISE][SEMANTIC_START]x[SEMANTIC_END][FROM][SEMANTIC_START]y[SEMANTIC_END]
#
#
# example:
# assert x,y
#
# parsed:
# [ASSERT][SEMANTIC_START]x[SEMANTIC_END][COMMA][SEMANTIC_START]y[SEMANTIC_END]
#
#
# example:
# del x,y,z
#
# parsed:
# [DEL][SEMANTIC_START]x[SEMANTIC_END][COMMA][SEMANTIC_START]y[SEMANTIC_END][COMMA][SEMANTIC_START]z[SEMANTIC_END]
#
#
# example:
# pass
#
# parsed:
# [PASS]
#
#
# example:
# if x:
#    ...
# elif y:
#    ...
# else:
#    ...
#
# parsed:
# [IF][SEMANTIC_START]x[SEMANTIC_END][BLOCK][NEW_LINE][INDENT][ELLIPSIS][NEW_LINE][ELIF][SEMANTIC_START]y[SEMANTIC_END][BLOCK][NEW_LINE][INDENT][ELLIPSIS][NEW_LINE][ELSE][BLOCK][NEW_LINE][INDENT][ELLIPSIS]
#
#
# example:
# for x in y:
#     ...
# else:
#     ...
#
# parsed:
# [FOR][SEMANTIC_START]x[SEMANTIC_END][IN][SEMANTIC_START]y[SEMANTIC_END][BLOCK][NEW_LINE][INDENT][ELLIPSIS][NEW_LINE][ELSE][BLOCK][NEW_LINE][INDENT][ELLIPSIS]
#
#
# example:
# while x:
#    ...
# else:
#    ...
#
# parsed:
# [WHILE][SEMANTIC_START]x[SEMANTIC_END][BLOCK][NEW_LINE][INDENT][ELLIPSIS][NEW_LINE][ELSE][BLOCK][NEW_LINE][INDENT][ELLIPSIS]
#
#
# example:
# for a in b:
#     if a > 5:
#         break
#     else:
#         continue
#
# parsed:
# [FOR][SEMANTIC_START]a[SEMANTIC_END][IN][SEMANTIC_START]b[SEMANTIC_END][BLOCK][NEW_LINE][INDENT][IF][SEMANTIC_START]a[SEMANTIC_END][GT][SEMANTIC_START]5[SEMANTIC_END][BLOCK][NEW_LINE][INDENT][INDENT][BREAK][NEW_LINE][INDENT][ELSE][BLOCK][NEW_LINE][INDENT][INDENT][CONTINUE]
#
#
# example:
# try:
#    ...
# except Exception:
#    ...
# except OtherException as e:
#    ...
# else:
#    ...
# finally:
#    ...
#
# parsed:
# [TRY][BLOCK][NEW_LINE][INDENT][ELLIPSIS][NEW_LINE][EXCEPT][SEMANTIC_START]Exception[SEMANTIC_END][BLOCK][NEW_LINE][INDENT][ELLIPSIS][NEW_LINE][EXCEPT][SEMANTIC_START]OtherException[SEMANTIC_END][AS]e[BLOCK][NEW_LINE][INDENT][ELLIPSIS][NEW_LINE][ELSE][BLOCK][NEW_LINE][INDENT][ELLIPSIS][NEW_LINE][FINALLY][BLOCK][NEW_LINE][INDENT][ELLIPSIS]
#
#
# example:
# try:
#    ...
# except* Exception:
#    ...
#
# parsed:
# [TRY][BLOCK][NEW_LINE][INDENT][ELLIPSIS][NEW_LINE][EXCEPT*][SEMANTIC_START]Exception[SEMANTIC_END][BLOCK][NEW_LINE][INDENT][ELLIPSIS]
#
#
# example:
# try:
#     a + 1
# except TypeError:
#     pass
#
# parsed:
# [TRY][BLOCK][NEW_LINE][INDENT][SEMANTIC_START]a[SEMANTIC_END][ADD][SEMANTIC_START]1[SEMANTIC_END][NEW_LINE][EXCEPT][SEMANTIC_START]TypeError[SEMANTIC_END][BLOCK][NEW_LINE][INDENT][PASS]
#
#
# example:
# with a as b, c as d:
#    something(b, d)
#
# parsed:
# [WITH][SEMANTIC_START]a[SEMANTIC_END][AS_ITEM][SEMANTIC_START]b[SEMANTIC_END][COMMA][SEMANTIC_START]c[SEMANTIC_END][AS_ITEM][SEMANTIC_START]d[SEMANTIC_END][BLOCK][NEW_LINE][INDENT][SEMANTIC_START]something[SEMANTIC_END][DELIMIT_1_L][SEMANTIC_START]b[SEMANTIC_END][COMMA][SEMANTIC_START]d[SEMANTIC_END][DELIMIT_1_R]
#
#
# example:
# lambda x,y: ...
#
# parsed:
# [LAMBDA][SEMANTIC_START]x[SEMANTIC_END][COMMA][SEMANTIC_START]y[SEMANTIC_END][LAMBDA_BODDY][ELLIPSIS]
#
#
# example:
# def f(a: 'annotation', b=1, c=2, *d, e, f=3, **g):
#     pass
#
# parsed:
# [DEF]f[DELIMIT_1_L][SEMANTIC_START]a[SEMANTIC_END][COMMA][SEMANTIC_START]b[SEMANTIC_END][ASSIGN][SEMANTIC_START]1[SEMANTIC_END][COMMA][SEMANTIC_START]c[SEMANTIC_END][ASSIGN][SEMANTIC_START]2[SEMANTIC_END][COMMA][REFERENCE][SEMANTIC_START]d[SEMANTIC_END][COMMA][SEMANTIC_START]e[SEMANTIC_END][COMMA][SEMANTIC_START]f[SEMANTIC_END][ASSIGN][SEMANTIC_START]3[SEMANTIC_END][COMMA][KWARGS][SEMANTIC_START]g[SEMANTIC_END][DELIMIT_1_R][BLOCK][NEW_LINE][INDENT][PASS]
#
#
# example:
# return 4
#
# parsed:
# [RETURN][SEMANTIC_START]4[SEMANTIC_END]
#
#
# example:
# yield x
#
# parsed:
# [YIELD][SEMANTIC_START]x[SEMANTIC_END]
#
#
# example:
# yield from x
#
# parsed:
# [YIELD_FROM][SEMANTIC_START]x[SEMANTIC_END]
#
#
# example:
# class Foo(base1, base2, metaclass=meta):
#     pass
#
# parsed:
# [CLASS]Foo[DELIMIT_1_L][SEMANTIC_START]base1[SEMANTIC_END][COMMA][SEMANTIC_START]base2[SEMANTIC_END][COMMA][SEMANTIC_START]metaclass[SEMANTIC_END][ASSIGN][SEMANTIC_START]meta[SEMANTIC_END][DELIMIT_1_R][BLOCK][NEW_LINE][INDENT][PASS]
#
#
# example:
# async def f():
#     await other_func()
#
# parsed:
# [ASYNC_DEF]f[DELIMIT_1_L][DELIMIT_1_R][BLOCK][NEW_LINE][INDENT][AWAIT][SEMANTIC_START]other_func[SEMANTIC_END][DELIMIT_1_L][DELIMIT_1_R]
#
#
# example:
# match x:
#     case Point2D(0, 0):
#         ...
#     case Point3D(x=0, y=0, z=0):
#         ...
#
# parsed:
# [MATCH][SEMANTIC_START]x[SEMANTIC_END][BLOCK][NEW_LINE][INDENT][CASE][SEMANTIC_START]Point2D[SEMANTIC_END][DELIMIT_1_L][SEMANTIC_START]0[SEMANTIC_END][COMMA][SEMANTIC_START]0[SEMANTIC_END][DELIMIT_1_R][BLOCK][NEW_LINE][INDENT][INDENT][ELLIPSIS][NEW_LINE][INDENT][CASE][SEMANTIC_START]Point3D[SEMANTIC_END][DELIMIT_1_L][SEMANTIC_START]x[SEMANTIC_END][ASSIGN][SEMANTIC_START]0[SEMANTIC_END][COMMA][SEMANTIC_START]y[SEMANTIC_END][ASSIGN][SEMANTIC_START]0[SEMANTIC_END][COMMA][SEMANTIC_START]z[SEMANTIC_END][ASSIGN][SEMANTIC_START]0[SEMANTIC_END][DELIMIT_1_R][BLOCK][NEW_LINE][INDENT][INDENT][ELLIPSIS]
#
#
# example:
# match x:
#     case [x] as y:
#         ...
#     case _:
#         ...
#
# parsed:
# [MATCH][SEMANTIC_START]x[SEMANTIC_END][BLOCK][NEW_LINE][INDENT][CASE][DELIMIT_2_L][SEMANTIC_START]x[SEMANTIC_END][DELIMIT_2_R][MATCH_AS][SEMANTIC_START]y[SEMANTIC_END][BLOCK][NEW_LINE][INDENT][INDENT][ELLIPSIS][NEW_LINE][INDENT][CASE][MATCH_DEFAULT][BLOCK][NEW_LINE][INDENT][INDENT][ELLIPSIS]
#
#
# example:
# match x:
#     case Point2D(0, 0):
#         ...
#     case Point3D(x=0, y=0, z=0):
#         ...
#
# parsed:
# [MATCH][SEMANTIC_START]x[SEMANTIC_END][BLOCK][NEW_LINE][INDENT][CASE][SEMANTIC_START]Point2D[SEMANTIC_END][DELIMIT_1_L][SEMANTIC_START]0[SEMANTIC_END][COMMA][SEMANTIC_START]0[SEMANTIC_END][DELIMIT_1_R][BLOCK][NEW_LINE][INDENT][INDENT][ELLIPSIS][NEW_LINE][INDENT][CASE][SEMANTIC_START]Point3D[SEMANTIC_END][DELIMIT_1_L][SEMANTIC_START]x[SEMANTIC_END][ASSIGN][SEMANTIC_START]0[SEMANTIC_END][COMMA][SEMANTIC_START]y[SEMANTIC_END][ASSIGN][SEMANTIC_START]0[SEMANTIC_END][COMMA][SEMANTIC_START]z[SEMANTIC_END][ASSIGN][SEMANTIC_START]0[SEMANTIC_END][DELIMIT_1_R][BLOCK][NEW_LINE][INDENT][INDENT][ELLIPSIS]
#
#
# example:
# match x:
#     case {1: _, 2: _}:
#         ...
#     case {**rest}:
#         ...
#
# parsed:
# [MATCH][SEMANTIC_START]x[SEMANTIC_END][BLOCK][NEW_LINE][INDENT][CASE][DELIMIT_3_L][SEMANTIC_START]1[SEMANTIC_END][DICT_COLON][MATCH_DEFAULT][COMMA][SEMANTIC_START]2[SEMANTIC_END][DICT_COLON][MATCH_DEFAULT][DELIMIT_3_R][BLOCK][NEW_LINE][INDENT][INDENT][ELLIPSIS][NEW_LINE][INDENT][CASE][DELIMIT_3_L][UNPACK][SEMANTIC_START]rest[SEMANTIC_END][DELIMIT_3_R][BLOCK][NEW_LINE][INDENT][INDENT][ELLIPSIS]
#
#
# example:
# match x:
#     case [1, 2, *rest]:
#         ...
#     case [*_]:
#         ...
#
# parsed:
# [MATCH][SEMANTIC_START]x[SEMANTIC_END][BLOCK][NEW_LINE][INDENT][CASE][DELIMIT_2_L][SEMANTIC_START]1[SEMANTIC_END][COMMA][SEMANTIC_START]2[SEMANTIC_END][COMMA][MATCH_STAR][SEMANTIC_START]rest[SEMANTIC_END][DELIMIT_2_R][BLOCK][NEW_LINE][INDENT][INDENT][ELLIPSIS][NEW_LINE][INDENT][CASE][DELIMIT_2_L][MATCH_STAR][SEMANTIC_START][MATCH_DEFAULT][SEMANTIC_END][DELIMIT_2_R][BLOCK][NEW_LINE][INDENT][INDENT][ELLIPSIS]
#
#
# example:
# match x:
#     case [1, 2]:
#         ...
#
# parsed:
# [MATCH][SEMANTIC_START]x[SEMANTIC_END][BLOCK][NEW_LINE][INDENT][CASE][DELIMIT_2_L][SEMANTIC_START]1[SEMANTIC_END][COMMA][SEMANTIC_START]2[SEMANTIC_END][DELIMIT_2_R][BLOCK][NEW_LINE][INDENT][INDENT][ELLIPSIS]
#
#
# example:
# match x:
#     case None:
#         ...
#
# parsed:
# [MATCH][SEMANTIC_START]x[SEMANTIC_END][BLOCK][NEW_LINE][INDENT][CASE][SEMANTIC_START]None[SEMANTIC_END][BLOCK][NEW_LINE][INDENT][INDENT][ELLIPSIS]
#
#
# example:
# match x:
#     case "Relevant":
#         ...
#
# parsed:
# [MATCH][SEMANTIC_START]x[SEMANTIC_END][BLOCK][NEW_LINE][INDENT][CASE][QUOT_1][SEMANTIC_START]Relevant[SEMANTIC_END][QUOT_1][BLOCK][NEW_LINE][INDENT][INDENT][ELLIPSIS]
#
#
# example:
# match x:
#     case [x] if x>0:
#         ...
#     case tuple():
#         ...
#
# parsed:
# [MATCH][SEMANTIC_START]x[SEMANTIC_END][BLOCK][NEW_LINE][INDENT][CASE][DELIMIT_2_L][SEMANTIC_START]x[SEMANTIC_END][DELIMIT_2_R][GUARD][SEMANTIC_START]x[SEMANTIC_END][GT][SEMANTIC_START]0[SEMANTIC_END][BLOCK][NEW_LINE][INDENT][INDENT][ELLIPSIS][NEW_LINE][INDENT][CASE][SEMANTIC_START]tuple[SEMANTIC_END][DELIMIT_1_L][DELIMIT_1_R][BLOCK][NEW_LINE][INDENT][INDENT][ELLIPSIS]
#
#
# example:
# match x:
#     case [x] | (y):
#         ...
#
# parsed:
# [MATCH][SEMANTIC_START]x[SEMANTIC_END][BLOCK][NEW_LINE][INDENT][CASE][DELIMIT_2_L][SEMANTIC_START]x[SEMANTIC_END][DELIMIT_2_R][MATCH_OR][SEMANTIC_START]y[SEMANTIC_END][BLOCK][NEW_LINE][INDENT][INDENT][ELLIPSIS]

# %% [markdown]
# ## Reverse pretokenization

# %% [markdown]
# without dedent

# %%
pretokenizer = FirstPretokenizer(_use_dedent=False, _use_semantics=True)

# %%
for example in examples:
    parsed = pretokenizer.pretokenize(ast.parse(example))
    print(f"example:\n{example}\n\nparsed:\n{pretokenizer.reverse(parsed)}\n\n")
# Out:
# example:
# 123
#
# parsed:
# 123
#
#
# example:
# f"sin({a}) is {sin(a):.3}"
#
# parsed:
# f"sin({a}) is {sin(a)}"
#
#
# example:
# [1, 2, 3]
#
# parsed:
# [1, 2, 3]
#
#
# example:
# (1, 2, 3)
#
# parsed:
# (1, 2, 3)
#
#
# example:
# {1, 2, 3}
#
# parsed:
# {1, 2, 3}
#
#
# example:
# {"a":1, **d}
#
# parsed:
# {'a': 1, **d}
#
#
# example:
# a
#
# parsed:
# a
#
#
# example:
# a = 1
#
# parsed:
# a = 1
#
#
# example:
# del a
#
# parsed:
# del a
#
#
# example:
# a, *b = it
#
# parsed:
# a, *b = it
#
#
# example:
# -a
#
# parsed:
# -a
#
#
# example:
# not x
#
# parsed:
# not x
#
#
# example:
# x + y
#
# parsed:
# x + y
#
#
# example:
# x or y
#
# parsed:
# x or y
#
#
# example:
# 1 <= a < 10
#
# parsed:
# 1 <= a < 10
#
#
# example:
# func(a, b=c, *d, **e)
#
# parsed:
# func(a, *d, b = c, **e)
#
#
# example:
# a if b else c
#
# parsed:
# a if b else c
#
#
# example:
# snake.colour
#
# parsed:
# snake.colour
#
#
# example:
# (x := 4)
#
# parsed:
# (x := 4)
#
#
# example:
# l[1:2, 3]
#
# parsed:
# l[1:2, 3]
#
#
# example:
# l[1:2]
#
# parsed:
# l[1:2]
#
#
# example:
# [x for x in numbers]
#
# parsed:
# [x for x in numbers]
#
#
# example:
# {x: x**2 for x in numbers}
#
# parsed:
# {x: x**2 for x in numbers}
#
#
# example:
# {x for x in numbers}
#
# parsed:
# {x for x in numbers}
#
#
# example:
# [ord(c) for line in file for c in line]
#
# parsed:
# [ord(c) for line in file for c in line]
#
#
# example:
# (n**2 for n in it if n>5 if n<10)
#
# parsed:
# (n**2 for n in it if n > 5 if n < 10)
#
#
# example:
# [i async for i in soc]
#
# parsed:
# [i async for i in soc]
#
#
# example:
# a = b = 1
#
# parsed:
# a = b = 1
#
#
# example:
# a,b = c
#
# parsed:
# a, b = c
#
#
# example:
# x += 2
#
# parsed:
# x += 2
#
#
# example:
# raise x from y
#
# parsed:
# raise x from y
#
#
# example:
# assert x,y
#
# parsed:
# assert x, y
#
#
# example:
# del x,y,z
#
# parsed:
# del x, y, z
#
#
# example:
# pass
#
# parsed:
# pass
#
#
# example:
# if x:
#    ...
# elif y:
#    ...
# else:
#    ...
#
# parsed:
# if x:
#     ...
# elif y:
#     ...
# else:
#     ...
#
#
# example:
# for x in y:
#     ...
# else:
#     ...
#
# parsed:
# for x in y:
#     ...
# else:
#     ...
#
#
# example:
# while x:
#    ...
# else:
#    ...
#
# parsed:
# while x:
#     ...
# else:
#     ...
#
#
# example:
# for a in b:
#     if a > 5:
#         break
#     else:
#         continue
#
# parsed:
# for a in b:
#     if a > 5:
#         break
#     else:
#         continue
#
#
# example:
# try:
#    ...
# except Exception:
#    ...
# except OtherException as e:
#    ...
# else:
#    ...
# finally:
#    ...
#
# parsed:
# try:
#     ...
# except Exception:
#     ...
# except OtherException as e:
#     ...
# else:
#     ...
# finally:
#     ...
#
#
# example:
# try:
#    ...
# except* Exception:
#    ...
#
# parsed:
# try:
#     ...
# except* Exception:
#     ...
#
#
# example:
# try:
#     a + 1
# except TypeError:
#     pass
#
# parsed:
# try:
#     a + 1
# except TypeError:
#     pass
#
#
# example:
# with a as b, c as d:
#    something(b, d)
#
# parsed:
# with a as b, c as d:
#     something(b, d)
#
#
# example:
# lambda x,y: ...
#
# parsed:
# lambda x, y: ...
#
#
# example:
# def f(a: 'annotation', b=1, c=2, *d, e, f=3, **g):
#     pass
#
# parsed:
# def f(a, b = 1, c = 2, *d, e, f = 3, **g):
#     pass
#
#
# example:
# return 4
#
# parsed:
# return 4
#
#
# example:
# yield x
#
# parsed:
# yield x
#
#
# example:
# yield from x
#
# parsed:
# yield from x
#
#
# example:
# class Foo(base1, base2, metaclass=meta):
#     pass
#
# parsed:
# class Foo(base1, base2, metaclass = meta):
#     pass
#
#
# example:
# async def f():
#     await other_func()
#
# parsed:
# async def f():
#     await other_func()
#
#
# example:
# match x:
#     case Point2D(0, 0):
#         ...
#     case Point3D(x=0, y=0, z=0):
#         ...
#
# parsed:
# match x:
#     case Point2D(0, 0):
#         ...
#     case Point3D(x = 0, y = 0, z = 0):
#         ...
#
#
# example:
# match x:
#     case [x] as y:
#         ...
#     case _:
#         ...
#
# parsed:
# match x:
#     case [x] as y:
#         ...
#     case _:
#         ...
#
#
# example:
# match x:
#     case Point2D(0, 0):
#         ...
#     case Point3D(x=0, y=0, z=0):
#         ...
#
# parsed:
# match x:
#     case Point2D(0, 0):
#         ...
#     case Point3D(x = 0, y = 0, z = 0):
#         ...
#
#
# example:
# match x:
#     case {1: _, 2: _}:
#         ...
#     case {**rest}:
#         ...
#
# parsed:
# match x:
#     case {1: _, 2: _}:
#         ...
#     case {**rest}:
#         ...
#
#
# example:
# match x:
#     case [1, 2, *rest]:
#         ...
#     case [*_]:
#         ...
#
# parsed:
# match x:
#     case [1, 2, *rest]:
#         ...
#     case [*_]:
#         ...
#
#
# example:
# match x:
#     case [1, 2]:
#         ...
#
# parsed:
# match x:
#     case [1, 2]:
#         ...
#
#
# example:
# match x:
#     case None:
#         ...
#
# parsed:
# match x:
#     case None:
#         ...
#
#
# example:
# match x:
#     case "Relevant":
#         ...
#
# parsed:
# match x:
#     case 'Relevant':
#         ...
#
#
# example:
# match x:
#     case [x] if x>0:
#         ...
#     case tuple():
#         ...
#
# parsed:
# match x:
#     case [x] if x > 0:
#         ...
#     case tuple():
#         ...
#
#
# example:
# match x:
#     case [x] | (y):
#         ...
#
# parsed:
# match x:
#     case [x] | y:
#         ...

# %% [markdown]
# with dedent

# %%
pretokenizer = FirstPretokenizer(_use_dedent=True, _use_semantics=True)

# %%
for example in examples:
    parsed = pretokenizer.pretokenize(ast.parse(example))
    print(f"example:\n{example}\n\nparsed:\n{pretokenizer.reverse(parsed)}\n\n")
# Out:
# example:
# 123
#
# parsed:
# 123
#
#
# example:
# f"sin({a}) is {sin(a):.3}"
#
# parsed:
# f"sin({a}) is {sin(a)}"
#
#
# example:
# [1, 2, 3]
#
# parsed:
# [1, 2, 3]
#
#
# example:
# (1, 2, 3)
#
# parsed:
# (1, 2, 3)
#
#
# example:
# {1, 2, 3}
#
# parsed:
# {1, 2, 3}
#
#
# example:
# {"a":1, **d}
#
# parsed:
# {'a': 1, **d}
#
#
# example:
# a
#
# parsed:
# a
#
#
# example:
# a = 1
#
# parsed:
# a = 1
#
#
# example:
# del a
#
# parsed:
# del a
#
#
# example:
# a, *b = it
#
# parsed:
# a, *b = it
#
#
# example:
# -a
#
# parsed:
# -a
#
#
# example:
# not x
#
# parsed:
# not x
#
#
# example:
# x + y
#
# parsed:
# x + y
#
#
# example:
# x or y
#
# parsed:
# x or y
#
#
# example:
# 1 <= a < 10
#
# parsed:
# 1 <= a < 10
#
#
# example:
# func(a, b=c, *d, **e)
#
# parsed:
# func(a, *d, b = c, **e)
#
#
# example:
# a if b else c
#
# parsed:
# a if b else c
#
#
# example:
# snake.colour
#
# parsed:
# snake.colour
#
#
# example:
# (x := 4)
#
# parsed:
# (x := 4)
#
#
# example:
# l[1:2, 3]
#
# parsed:
# l[1:2, 3]
#
#
# example:
# l[1:2]
#
# parsed:
# l[1:2]
#
#
# example:
# [x for x in numbers]
#
# parsed:
# [x for x in numbers]
#
#
# example:
# {x: x**2 for x in numbers}
#
# parsed:
# {x: x**2 for x in numbers}
#
#
# example:
# {x for x in numbers}
#
# parsed:
# {x for x in numbers}
#
#
# example:
# [ord(c) for line in file for c in line]
#
# parsed:
# [ord(c) for line in file for c in line]
#
#
# example:
# (n**2 for n in it if n>5 if n<10)
#
# parsed:
# (n**2 for n in it if n > 5 if n < 10)
#
#
# example:
# [i async for i in soc]
#
# parsed:
# [i async for i in soc]
#
#
# example:
# a = b = 1
#
# parsed:
# a = b = 1
#
#
# example:
# a,b = c
#
# parsed:
# a, b = c
#
#
# example:
# x += 2
#
# parsed:
# x += 2
#
#
# example:
# raise x from y
#
# parsed:
# raise x from y
#
#
# example:
# assert x,y
#
# parsed:
# assert x, y
#
#
# example:
# del x,y,z
#
# parsed:
# del x, y, z
#
#
# example:
# pass
#
# parsed:
# pass
#
#
# example:
# if x:
#    ...
# elif y:
#    ...
# else:
#    ...
#
# parsed:
# if x:
#     ...
# elif y:
#     ...
# else:
#     ...
#
#
#
# example:
# for x in y:
#     ...
# else:
#     ...
#
# parsed:
# for x in y:
#     ...
# else:
#     ...
#
#
#
# example:
# while x:
#    ...
# else:
#    ...
#
# parsed:
# while x:
#     ...
# else:
#     ...
#
#
#
# example:
# for a in b:
#     if a > 5:
#         break
#     else:
#         continue
#
# parsed:
# for a in b:
#     if a > 5:
#         break
#     else:
#         continue
#
#
#
#
# example:
# try:
#    ...
# except Exception:
#    ...
# except OtherException as e:
#    ...
# else:
#    ...
# finally:
#    ...
#
# parsed:
# try:
#     ...
# except Exception:
#     ...
# except OtherException as e:
#     ...
# else:
#     ...
# finally:
#     ...
#
#
#
# example:
# try:
#    ...
# except* Exception:
#    ...
#
# parsed:
# try:
#     ...
# except* Exception:
#     ...
#
#
#
# example:
# try:
#     a + 1
# except TypeError:
#     pass
#
# parsed:
# try:
#     a + 1
# except TypeError:
#     pass
#
#
#
# example:
# with a as b, c as d:
#    something(b, d)
#
# parsed:
# with a as b, c as d:
#     something(b, d)
#
#
#
# example:
# lambda x,y: ...
#
# parsed:
# lambda x, y: ...
#
#
# example:
# def f(a: 'annotation', b=1, c=2, *d, e, f=3, **g):
#     pass
#
# parsed:
# def f(a, b = 1, c = 2, *d, e, f = 3, **g):
#     pass
#
#
#
# example:
# return 4
#
# parsed:
# return 4
#
#
# example:
# yield x
#
# parsed:
# yield x
#
#
# example:
# yield from x
#
# parsed:
# yield from x
#
#
# example:
# class Foo(base1, base2, metaclass=meta):
#     pass
#
# parsed:
# class Foo(base1, base2, metaclass = meta):
#     pass
#
#
#
# example:
# async def f():
#     await other_func()
#
# parsed:
# async def f():
#     await other_func()
#
#
#
# example:
# match x:
#     case Point2D(0, 0):
#         ...
#     case Point3D(x=0, y=0, z=0):
#         ...
#
# parsed:
# match x:
#     case Point2D(0, 0):
#         ...
#     case Point3D(x = 0, y = 0, z = 0):
#         ...
#
#
#
#
# example:
# match x:
#     case [x] as y:
#         ...
#     case _:
#         ...
#
# parsed:
# match x:
#     case [x] as y:
#         ...
#     case _:
#         ...
#
#
#
#
# example:
# match x:
#     case Point2D(0, 0):
#         ...
#     case Point3D(x=0, y=0, z=0):
#         ...
#
# parsed:
# match x:
#     case Point2D(0, 0):
#         ...
#     case Point3D(x = 0, y = 0, z = 0):
#         ...
#
#
#
#
# example:
# match x:
#     case {1: _, 2: _}:
#         ...
#     case {**rest}:
#         ...
#
# parsed:
# match x:
#     case {1: _, 2: _}:
#         ...
#     case {**rest}:
#         ...
#
#
#
#
# example:
# match x:
#     case [1, 2, *rest]:
#         ...
#     case [*_]:
#         ...
#
# parsed:
# match x:
#     case [1, 2, *rest]:
#         ...
#     case [*_]:
#         ...
#
#
#
#
# example:
# match x:
#     case [1, 2]:
#         ...
#
# parsed:
# match x:
#     case [1, 2]:
#         ...
#
#
#
#
# example:
# match x:
#     case None:
#         ...
#
# parsed:
# match x:
#     case None:
#         ...
#
#
#
#
# example:
# match x:
#     case "Relevant":
#         ...
#
# parsed:
# match x:
#     case 'Relevant':
#         ...
#
#
#
#
# example:
# match x:
#     case [x] if x>0:
#         ...
#     case tuple():
#         ...
#
# parsed:
# match x:
#     case [x] if x > 0:
#         ...
#     case tuple():
#         ...
#
#
#
#
# example:
# match x:
#     case [x] | (y):
#         ...
#
# parsed:
# match x:
#     case [x] | y:
#         ...
